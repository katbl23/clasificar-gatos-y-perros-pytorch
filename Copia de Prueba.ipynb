# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/.git/

# %%
# !git config --global user.email "kt01@hotmail.es"
# !git config --global user.name "ktbl23"

# %%
# !git add .

# %%
# !git commit -m "Subir archivo inicial"
# Out:
# [master (root-commit) 8e898d0] Subir archivo inicial
#  80 files changed, 50523 insertions(+)
#  create mode 100644 01 - Python + Jupyter.ipynb
#  create mode 100644 02 - Tipos de datos y operadores.ipynb
#  create mode 100644 03 - Estructuras de datos.ipynb
#  create mode 100644 04 - Fundamentos librerias DS Python.ipynb
#  create mode 100644 05 - Estadistica Basica Python.ipynb
#  create mode 100644 06 - Python Clases Funciones.ipynb
#  create mode 100644 07 - Metodologias de pre-procesamiento, limpieza y calidad de datos (2).ipynb
#  create mode 100644 07 - Metodologias de pre-procesamiento, limpieza y calidad de datos.ipynb
#  create mode 100644 08 - Preprocesamiento Caso Cotton_Plus.ipynb
#  create mode 100644 09 - Introduccion Algebra Lineal.ipynb
#  create mode 100644 "10 - Introduccion Regresio\314\201n Lineal.ipynb"
#  create mode 100644 13_Clustering_KMeans (1).ipynb
#  create mode 100644 13_Clustering_KMeans.ipynb
#  create mode 100644 "14 - A\314\201rboles de Decisio\314\201n.ipynb"
#  create mode 100644 Analisis financiero
#  create mode 100644 "Ana\342\225\240u\314\210lisis_de_experimentos.ipynb"
#  create mode 100644 Breast Cancer.ipynb
#  create mode 100644 "Copia de Copia de Reto tecnolo\314\201gico"
#  create mode 100644 Copia de clasificar gatos y perros pytorch.ipynb
#  create mode 100644 Copia de predicion_de_raiting_libros (1).ipynb
#  create mode 100644 Copia de predicion_de_raiting_libros.ipynb
#  create mode 100644 Corrector ortografico en python.ipynb
#  create mode 100644 "Curso_de_Estadi\314\201stica_Parte_3.ipynb"
#  create mode 100644 Data Visualization: Explorando con Seaborn.ipynb
#  create mode 100644 Ejercicio_numpy_algebra (1).ipynb
#  create mode 100644 Ejercicio_numpy_algebra.ipynb
#  create mode 100644 Importando_pickle.ipynb
#  create mode 100644 Inmersion_de_datos_clase_uno.ipynb
#  create mode 100644 Machine Learning Clasificacion.ipynb
#  create mode 100644 NLP.ipynb
#  create mode 100644 NLP_final.ipynb
#  create mode 100644 Nlp y regex.ipynb
#  create mode 100644 PLN analisis de sentimientos.ipynb
#  create mode 100644 Pandas_IO.ipynb
#  create mode 100644 Phytonpandas.ipynb
#  create mode 100644 Predicion_de_raiting_libros.ipynb
#  create mode 100644 "Proyecto_Estadi\314\201stica.ipynb"
#  create mode 100644 Proyecto_final.ipynb
#  create mode 100644 Prueba.ipynb
#  create mode 100644 Python_Tratamiento_de_datos.ipynb
#  create mode 100644 Python_introduccion.ipynb
#  create mode 100644 Python_numpy.ipynb
#  create mode 100644 Python_para_Data_Science_Pandas.ipynb
#  create mode 100644 Red_Neuronal_Pytorch_clasificacion_de_ropa.ipynb
#  create mode 100644 "Regresio\314\201n_Lineal_Exerjicio.ipynb"
#  create mode 100644 "Regresio\314\201n_Lineal_proyecto_cerveza_pickle.ipynb"
#  create mode 100644 Simulador casas.ipynb
#  create mode 100644 Tarea.ipynb
#  create mode 100644 "Teori\314\201a Proyecto Muestra Hogares.ipynb"
#  create mode 100644 Untitled
#  create mode 100644 Untitled (1)
#  create mode 100644 Untitled (2)
#  create mode 100644 Untitled (3)
#  create mode 100644 Untitled (4)
#  create mode 100644 Untitled (5)
#  create mode 100644 Untitled (6)
#  create mode 100644 Untitled (7)
#  create mode 100644 Untitled (8)
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 Untitled1.ipynb
#  create mode 100644 Untitled2.ipynb
#  create mode 100644 Untitled3.ipynb
#  create mode 100644 Untitled4.ipynb
#  create mode 100644 Untitled5.ipynb
#  create mode 100644 Untitled6.ipynb
#  create mode 100644 Untitled7.ipynb
#  create mode 100644 Untitled8.ipynb
#  create mode 100644 "Version_katherine_Reto tecnolo\314\201gico"
#  create mode 100644 Visualizacion_Matplotlib.ipynb
#  create mode 100644 Web Scraping (1).ipynb
#  create mode 100644 Web Scraping.ipynb
#  create mode 100644 Word2Vec (1).ipynb
#  create mode 100644 Word2Vec.ipynb
#  create mode 100644 alura_tratamiento_de_datos.ipynb
#  create mode 100644 corrector-ortografico.ipynb
#  create mode 100644 cross-validate-evaluacion-modelos-aula-1.ipynb
#  create mode 100644 segmentos_de_clientes.ipynb
#  create mode 100644 tecnicas_de_clasificacion.ipynb
#  create mode 100644 word2vec_entrenamiento.ipynb
#  create mode 100644 word2vec_spacy.ipynb
