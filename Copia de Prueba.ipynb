# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !apt-get install -y git-credential-manager
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package git-credential-manager

# %%
# %cd '/content/drive/MyDrive/Claficacion de imagenes Pytorch'
# Out:
# /content/drive/MyDrive/Claficacion de imagenes Pytorch

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Claficacion de imagenes Pytorch/.git/

# %%
# !git config --global credential.helper cache
# !git config --global credential.helper 'cache --timeout=3600'

# %%
# !git config --global user.email "kt01@hotmail.es"
# !git config --global user.name "ktbl23"

# %%
# !git remote set-url origin https://katbl23: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@github.com/katbl23/clasificar-gatos-y-perros-pytorch.git

# %%
# !git config --global credential.helper manager

# %%
# !git add .

# %%
# !git commit -m "Subir archivo inicial"
# Out:
# [master dae366e] Subir archivo inicial
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git remote -v
# Out:
# origin	https://katbl23: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@github.com/katbl23/clasificar-gatos-y-perros-pytorch.git (fetch)
# origin	https://katbl23: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@github.com/katbl23/clasificar-gatos-y-perros-pytorch.git (push)

# %%
# !git push origin master
# Out:
# remote: Permission to katbl23/clasificar-gatos-y-perros-pytorch.git denied to katbl23.
# fatal: unable to access 'https://github.com/katbl23/clasificar-gatos-y-perros-pytorch.git/': The requested URL returned error: 403
