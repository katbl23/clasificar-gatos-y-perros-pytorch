# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Claficacion de imagenes Pytorch'
# Out:
# /content/drive/MyDrive/Claficacion de imagenes Pytorch

# %%
# !git init

# %%
# !git config --global credential.helper cache

# %%
# !git config --global user.email "kt01@hotmail.es"
# !git config --global user.name "ktbl23"

# %%
# !git add .

# %%
# !git commit -m "Subir archivo inicial"
# Out:
# [master (root-commit) f571a02] Subir archivo inicial
#  1 file changed, 1 insertion(+)
#  create mode 100644 Copia de Prueba.ipynb

# %%
# !git remote add origin https://github.com/katbl23/clasificar-gatos-y-perros-pytorch

# %%
# !git remote -v
# Out:
# origin	https://github.com/katbl23/clasificar-gatos-y-perros-pytorch (fetch)
# origin	https://github.com/katbl23/clasificar-gatos-y-perros-pytorch (push)

# %%
# !git push -u origin master
# Out:
# fatal: could not read Password for 'https://katbl23@github.com': No such device or address

# %%
# !git remote set-url origin https://katbl23@github.com/katbl23/clasificar-gatos-y-perros-pytorch.git
